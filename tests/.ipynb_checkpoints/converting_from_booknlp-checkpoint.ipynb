# %% [markdown]
# # Converting from booknlp
#
# Output e.g. from "Powerloom" on a novel. See folder of examples in GDrive.

# %%
# Output from Betsy Thoughtless
url= 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQwSK9xJUGBwkQ6PBKDBTnaSBreiAHNKdoYibqwrwOCZgGKyC4L1ij9W1PoXcbikkdG19aitmDmG7Ev/pub?gid=1189800899&single=true&output=csv'

# %%
import sys
sys.path.append('..')

# %%
import hairball as hb
import pandas as pd

# %%
df1=pd.read_csv(url)
df1
# Out:
#     id           name                                              names  \
# 0   36     miss Betsy  miss Betsy, Miss Betsy, miss Betsy Thoughtless...
# 1   26  mr. Trueworth            mr. Trueworth, Mr. Trueworth, Trueworth
# 2   43    mrs. Munden              mrs. Munden, Mrs. Munden, Mrs. munden
# 3   65    mr. Goodman  mr. Goodman, Mr. Goodman, mr. Edward Goodman, ...
# 4   67     mr. Munden         mr. Munden, Mr. Munden, Munden, mr. munden
# ..  ..            ...                                                ...
# 63  24      G. Munden                                          G. Munden
# 64  35        Bologne                                            Bologne
# 65  39    F. Mellasin                                        F. Mellasin
# 66  66      F. Fineer                                          F. Fineer
# 67  48   C. Trueworth                                       C. Trueworth
#
#         name_real   num   gender  race  class  other  notes
# ...

# %%
df=hb.condense_booknlp_output(df1)
df
# Out:
#                ID          Label  \
# 47     Miss Betsy     Miss Betsy
# 60  Mr. Trueworth  Mr. Trueworth
# 65    Mrs. Munden    Mrs. Munden
# 54    Mr. Goodman    Mr. Goodman
# 56     Mr. Munden     Mr. Munden
# ..            ...            ...
# 10      F. Fineer      F. Fineer
# 57     Mr. Saving     Mr. Saving
# 5    C. Trueworth   C. Trueworth
# 4         Bologne        Bologne
# 16      G. Munden      G. Munden
#
#                                                 Names   Num   gender  race  \
# 47  Betsy, Miss Betsy, Thoughtless, Betsy Thoughtl...  3306  unknown   NaN
# 60                           Mr. Trueworth, Trueworth  1510  unknown   NaN
# 65                           Mrs. Munden, Mrs. munden   816  unknown   NaN
# 54  Mr. Goodman, Mr. Edward Goodman, Edward Goodma...   730  unknown   NaN
# 56                     Munden, Mr. Munden, Mr. munden   728  unknown   NaN
# ..                                                ...   ...      ...   ...
# ...
